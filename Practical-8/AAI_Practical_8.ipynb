# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

def generate_data(n_samples=300, n_clusters=4, random_state=42):
    """Generate synthetic data using make_blobs."""
    X, _ = make_blobs(n_samples=n_samples, centers=n_clusters, cluster_std=0.60, random_state=random_state)
    return X

def kmeans_clustering(X, n_clusters=4):
    """Perform K-Means clustering on the given data."""
    kmeans = KMeans(n_clusters=n_clusters)
    y_kmeans = kmeans.fit_predict(X)
    return y_kmeans, kmeans.cluster_centers_

def plot_clusters(X, y_kmeans, centers):
    """Plot the clustered data and cluster centers."""
    plt.scatter(X[:, 0], X[:, 1], c=y_kmeans, s=50, cmap='viridis')
    plt.scatter(centers[:, 0], centers[:, 1], c='red', s=200, alpha=0.75, marker='X')
    plt.title('K-Means Clustering')
    plt.xlabel('Feature 1')
    plt.ylabel('Feature 2')
    plt.show()

def main():
    n_samples = 300
    n_clusters = 4

    print("Generating synthetic data...")
    X = generate_data(n_samples=n_samples, n_clusters=n_clusters)

    print("Performing K-Means clustering...")
    y_kmeans, centers = kmeans_clustering(X, n_clusters=n_clusters)

    print("Plotting clusters...")
    plot_clusters(X, y_kmeans, centers)

if __name__ == "__main__":
    main()
# Out:
# Generating synthetic data...
# Performing K-Means clustering...
# Plotting clusters...
